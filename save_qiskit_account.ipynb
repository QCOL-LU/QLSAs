# %%
from qiskit_ibm_runtime import QiskitRuntimeService

token = "<YOUR_TOKEN>"  # IBM Cloud API key
instance = "<YOUR_INSTANCE>"  # IBM Cloud CRN
name = "<YOUR_NAME>"

# save_account() persists credentials and returns None.
QiskitRuntimeService.save_account(
    channel="ibm_cloud",
    token=token,
    instance=instance,
    name=name,
    overwrite=True,
)

# Create a usable service client from the saved account.
service = QiskitRuntimeService(name=name)
