# %%
from qiskit_ibm_runtime import QiskitRuntimeService

token = "<YOUR_TOKEN>" #api key

instance = "<YOUR_INSTANCE>" #crn

name = "<YOUR_NAME>"

service = QiskitRuntimeService.save_account(
    token=token,
    instance=instance,
    name=name,
    overwrite=True
  )
